# %%
#!pip3 install numpy pandas scipy statsmodels
#!pip install gitpython
import git

# Replace <repository_url> with the actual repository URL
repository_url = "https://github.com/UcarLab/AMULET"

# Clone the repository into the current directory
repo = git.Repo.clone_from(repository_url, "AMULET")

# %%
# !chmod +x /volume/AMULET/AMULET.sh

# %%
# Sample 1
#!bash /volume/AMULET/AMULET.sh /volume/SAMPLE_1/atac_fragments.tsv.gz /volume/SAMPLE_1/singlecell.csv /volume/human_autosomes.txt /volume/blacklist_repeats_segdups_rmsk_hg38.bed /volume/SAMPLE_1/data/amulet_out/ /volume/AMULET/

# Sample 2
# !bash /volume/AMULET/AMULET.sh /volume/SAMPLE_2/atac_fragments.tsv.gz /volume/SAMPLE_2/singlecell.csv /volume/human_autosomes.txt /volume/blacklist_repeats_segdups_rmsk_hg38.bed /volume/SAMPLE_2/data/amulet_out/ /volume/AMULET/

# Sample 3
# !bash /volume/AMULET/AMULET.sh /volume/SAMPLE_3/atac_fragments.tsv.gz /volume/SAMPLE_3/singlecell.csv /volume/human_autosomes.txt /volume/blacklist_repeats_segdups_rmsk_hg38.bed /volume/SAMPLE_3/data/amulet_out/ /volume/AMULET/

# Sample 4
# !bash /volume/AMULET/AMULET.sh /volume/SAMPLE_4/atac_fragments.tsv.gz /volume/SAMPLE_4/singlecell.csv /volume/human_autosomes.txt /volume/blacklist_repeats_segdups_rmsk_hg38.bed /volume/SAMPLE_4/data/amulet_out/ /volume/AMULET/

# Sample 5
# !bash /volume/AMULET/AMULET.sh /volume/SAMPLE_5/atac_fragments.tsv.gz /volume/SAMPLE_5/singlecell.csv /volume/human_autosomes.txt /volume/blacklist_repeats_segdups_rmsk_hg38.bed /volume/SAMPLE_5/data/amulet_out/ /volume/AMULET/

# Sample 6
# !bash /volume/AMULET/AMULET.sh /volume/SAMPLE_6/atac_fragments.tsv.gz /volume/SAMPLE_6/singlecell.csv /volume/human_autosomes.txt /volume/blacklist_repeats_segdups_rmsk_hg38.bed /volume/SAMPLE_6/data/amulet_out/ /volume/AMULET/
# Out:
# /volume/AMULET//FragmentFileOverlapCounter.py:193: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   table = np.empty(shape=(len(overlapcounts),len(colnames)), dtype=np.object)
# Completed in 323.99234978000004 seconds.
# Total number of reads: 82917518
# Total number of cells: 7577
# Total number of overlapping segments: 59416452
# Average overlaps per segment: 1.0852691776345043
# Max overlaps in segment: 165
# Filtering regions.
# /volume/AMULET//AMULET.py:133: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# ...

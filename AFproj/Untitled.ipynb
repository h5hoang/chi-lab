# %%
library(dplyr)
library(Seurat)
library(patchwork)

author_dataset <- readRDS("/volume/AFproj/samples/human_seurat_object_Fig.1B.rds")
afib_dataset <- readRDS("/volume/AFproj/samples/afib_la_multiome_final.rds")
merged_sample <- readRDS("/volume/AFproj/samples/merged_afib_postHarmony.rds")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject

# %%
author_dataset@meta.data$celltype <- Idents(author_dataset)
author_dataset@meta.data
afib_dataset@meta.data
merged_sample@meta.data
colnames(merged_sample@meta.data)

#merged_sample@meta.data <- select(merged_sample@meta.data, -starts_with(c("gex","atac")))
#merged_sample@meta.data <- select(merged_sample@meta.data, -starts_with(c("nCount","nFeature","gex","atac")))
#merged_sample@meta.data <- select(merged_sample@meta.data, -c('nCount_ATAC','nFeature_ATAC','percent.mt','TSS.enrichment','TSS.percentile','barcode','is_cell','excluded_reason','RNA.weight','wsnn_res.0.8','scrublet_DropletType','scrublet_Scores','amulet_doubletType','all_doublets'))

merged_sample@meta.data
#sampletype <- combined_samples@meta.data$samplename
#cellnames <- rownames(seurat@meta.data)

#subset out cells from author in the merged sample set
# Out:
#                           orig.ident nCount_RNA nFeature_RNA group celltype
# mraf1_AAACCCACATCGTTCC-1  mraf1       3143      1161         mraf  MP & DC
# mraf1_AAACCCAGTGCATCTA-1  mraf1       3468      1114         mraf  Lymphocyte
# mraf1_AAACGAACACTAGGCC-1  mraf1       4753      1815         mraf  Mural cell
# mraf1_AAACGCTAGATACCAA-1  mraf1       2043       732         mraf  Lymphocyte
# mraf1_AAACGCTGTATCAGGG-1  mraf1       4065       982         mraf  Lymphocyte
# mraf1_AAACGCTTCGTGTGAT-1  mraf1       6150      1668         mraf  Lymphocyte
# mraf1_AAACGCTTCTTAATCC-1  mraf1       3714      1591         mraf  Lymphocyte
# mraf1_AAAGAACAGGTCCTGC-1  mraf1       6244      2117         mraf  Mural cell
# mraf1_AAAGAACTCGGTAACT-1  mraf1       3276       976         mraf  Lymphocyte
# mraf1_AAAGGATAGGGATGTC-1  mraf1       4699      1767         mraf  Mural cell
# mraf1_AAAGGATAGTCAGAGC-1  mraf1       3648      1290         mraf  Lymphocyte
# ...

# %%
head(merged_sample[, 1], 10)
# Out:
#                                 orig.ident nCount_RNA nFeature_RNA group
# author_mraf1_AAACCCACATCGTTCC-1 mraf1      3143       1161         mraf
#                                 seurat_clusters condition clusters2 cell sex
# author_mraf1_AAACCCACATCGTTCC-1 15              NA        NA        NA   NA
#                                 age hypertension HF diabetes donor
# author_mraf1_AAACCCACATCGTTCC-1 NA  NA           NA NA       NA
#                                 RNA_snn_res.0.5 nCount_SCT nFeature_SCT
# author_mraf1_AAACCCACATCGTTCC-1 15              3637       1160
#                                 nCount_integrated nFeature_integrated
# author_mraf1_AAACCCACATCGTTCC-1 0                 0

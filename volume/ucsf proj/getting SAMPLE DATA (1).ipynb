# %%
import os

#SAMPLE 1
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/filtered_feature_bc_matrix.h5 /volume/SAMPLE_1/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/atac_fragments.tsv.gz /volume/SAMPLE_1/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/atac_fragments.tsv.gz.tbi /volume/SAMPLE_1/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/per_barcode_metrics.csv /volume/SAMPLE_1/data')

#SAMPLE 2
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/filtered_feature_bc_matrix.h5 /volume/SAMPLE_2/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/atac_fragments.tsv.gz /volume/SAMPLE_2/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/atac_fragments.tsv.gz.tbi /volume/SAMPLE_2/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/per_barcode_metrics.csv /volume/SAMPLE_2/data')

#SAMPLE 3
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/filtered_feature_bc_matrix.h5 /volume/SAMPLE_3/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/atac_fragments.tsv.gz /volume/SAMPLE_3/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/atac_fragments.tsv.gz.tbi /volume/SAMPLE_3/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/per_barcode_metrics.csv /volume/SAMPLE_3/data')

#SAMPLE 4
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/filtered_feature_bc_matrix.h5 /volume/SAMPLE_4/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/atac_fragments.tsv.gz /volume/SAMPLE_4/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/atac_fragments.tsv.gz.tbi /volume/SAMPLE_4/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/per_barcode_metrics.csv /volume/SAMPLE_4/data')

#SAMPLE 5
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/filtered_feature_bc_matrix.h5 /volume/SAMPLE_5/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/atac_fragments.tsv.gz /volume/SAMPLE_5/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/atac_fragments.tsv.gz.tbi /volume/SAMPLE_5/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/per_barcode_metrics.csv /volume/SAMPLE_5/data')

#SAMPLE 6
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/filtered_feature_bc_matrix.h5 /volume/SAMPLE_6/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/atac_fragments.tsv.gz /volume/SAMPLE_6/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/atac_fragments.tsv.gz.tbi /volume/SAMPLE_6/data')
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/per_barcode_metrics.csv /volume/SAMPLE_6/data')
# Out:
# Completed 38.3 MiB/41.3 MiB (44.0 MiB/s) with 1 file(s) remaining
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/filtered_feature_bc_matrix.h5 to SAMPLE_1/data/filtered_feature_bc_matrix.h5
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/atac_fragments.tsv.gz to SAMPLE_1/data/atac_fragments.tsv.gz
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/atac_fragments.tsv.gz.tbi to SAMPLE_1/data/atac_fragments.tsv.gz.tbi
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/per_barcode_metrics.csv to SAMPLE_1/data/per_barcode_metrics.csv
# download: s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/filtered_feature_bc_matrix.h5 to SAMPLE_2/data/filtered_feature_bc_matrix.h5
# download: s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/atac_fragments.tsv.gz to SAMPLE_2/data/atac_fragments.tsv.gz
# ...

# %% [markdown]
# # FILES FOR SCRUBLET

# %%
import os

# SAMPLE 1
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/filtered_feature_bc_matrix/ /volume/SAMPLE_1/data/ --recursive')

#SAMPLE 2
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/filtered_feature_bc_matrix/ /volume/SAMPLE_2/data/ --recursive')

#SAMPLE 3
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/filtered_feature_bc_matrix/ /volume/SAMPLE_3/data/ --recursive')

#SAMPLE 4
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/filtered_feature_bc_matrix/ /volume/SAMPLE_4/data/ --recursive')

#SAMPLE 5
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/filtered_feature_bc_matrix/ /volume/SAMPLE_5/data/ --recursive')

#SAMPLE 6
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/filtered_feature_bc_matrix/ /volume/SAMPLE_6/data/ --recursive')
# Out:
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/filtered_feature_bc_matrix/barcodes.tsv.gz to SAMPLE_1/data/barcodes.tsv.gz
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/filtered_feature_bc_matrix/features.tsv.gz to SAMPLE_1/data/features.tsv.gz
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/filtered_feature_bc_matrix/matrix.mtx.gz to SAMPLE_1/data/matrix.mtx.gz
# download: s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/filtered_feature_bc_matrix/barcodes.tsv.gz to SAMPLE_2/data/barcodes.tsv.gz
# download: s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/filtered_feature_bc_matrix/features.tsv.gz to SAMPLE_2/data/features.tsv.gz
# download: s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/filtered_feature_bc_matrix/matrix.mtx.gz to SAMPLE_2/data/matrix.mtx.gz
# ...

# %% [markdown]
# # FILES FOR AMULET

# %%
import os

# SAMPLE 1
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/per_barcode_metrics.csv /volume/SAMPLE_1/')

#SAMPLE 2
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/per_barcode_metrics.csv /volume/SAMPLE_2/')

#SAMPLE 3
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/per_barcode_metrics.csv /volume/SAMPLE_3/')

#SAMPLE 4
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/per_barcode_metrics.csv /volume/SAMPLE_4/')

#SAMPLE 5
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/per_barcode_metrics.csv /volume/SAMPLE_5/')

#SAMPLE 6
os.system('aws s3 cp s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/per_barcode_metrics.csv /volume/SAMPLE_6/')
# Out:
# Completed 51.3 MiB/63.5 MiB (37.6 MiB/s) with 1 file(s) remaining
# download: s3://preprocessed.data/ucsf_multiome_hearts/1029_CANAII_HSUE/outs/per_barcode_metrics.csv to SAMPLE_1/per_barcode_metrics.csv
# download: s3://preprocessed.data/ucsf_multiome_hearts/1514_CANAI_HSUE/outs/per_barcode_metrics.csv to SAMPLE_2/per_barcode_metrics.csv
# download: s3://preprocessed.data/ucsf_multiome_hearts/1940_SCOPE_DEEKS/outs/per_barcode_metrics.csv to SAMPLE_3/per_barcode_metrics.csv
# download: s3://preprocessed.data/ucsf_multiome_hearts/2185_SCOPE_DEEKS/outs/per_barcode_metrics.csv to SAMPLE_4/per_barcode_metrics.csv
# download: s3://preprocessed.data/ucsf_multiome_hearts/2642_CANAI_HSUE/outs/per_barcode_metrics.csv to SAMPLE_5/per_barcode_metrics.csv
# download: s3://preprocessed.data/ucsf_multiome_hearts/6501_SCOPE_DEEKS/outs/per_barcode_metrics.csv to SAMPLE_6/per_barcode_metrics.csv
# 0

# %%
#SAMPLE 1
# !cat /volume/SAMPLE_1/per_barcode_metrics.csv | cut -d, -f1,4 | sed "1s/.*/barcode,is__cell_barcode/" > /volume/SAMPLE_1/singlecell.csv

#SAMPLE 2
# !cat /volume/SAMPLE_2/per_barcode_metrics.csv | cut -d, -f1,4 | sed "1s/.*/barcode,is__cell_barcode/" > /volume/SAMPLE_2/singlecell.csv

#SAMPLE 3
# !cat /volume/SAMPLE_3/per_barcode_metrics.csv | cut -d, -f1,4 | sed "1s/.*/barcode,is__cell_barcode/" > /volume/SAMPLE_3/singlecell.csv

#SAMPLE 4
# !cat /volume/SAMPLE_4/per_barcode_metrics.csv | cut -d, -f1,4 | sed "1s/.*/barcode,is__cell_barcode/" > /volume/SAMPLE_4/singlecell.csv

#SAMPLE 5
# !cat /volume/SAMPLE_5/per_barcode_metrics.csv | cut -d, -f1,4 | sed "1s/.*/barcode,is__cell_barcode/" > /volume/SAMPLE_5/singlecell.csv

#SAMPLE 6
# !cat /volume/SAMPLE_6/per_barcode_metrics.csv | cut -d, -f1,4 | sed "1s/.*/barcode,is__cell_barcode/" > /volume/SAMPLE_6/singlecell.csv

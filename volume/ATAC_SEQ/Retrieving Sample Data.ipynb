# %%
import os

#SAMPLE 1
os.system('aws s3 cp s3://shaina/volume-archive/cellranger_out/EB_D3_R4/outs/fragments.tsv.gz /volume/NEW_ATAC_SEQ/rep_4/')
os.system('aws s3 cp s3://shaina/volume-archive/cellranger_out/EB_D3_R4/outs/fragments.tsv.gz.tbi /volume/NEW_ATAC_SEQ/rep_4/')

os.system('aws s3 cp s3://shaina/volume-archive/cellranger_out/EB_D3_R3/outs/fragments.tsv.gz /volume/NEW_ATAC_SEQ/rep_3/')
os.system('aws s3 cp s3://shaina/volume-archive/cellranger_out/EB_D3_R3/outs/fragments.tsv.gz.tbi /volume/NEW_ATAC_SEQ/rep_3/')

os.system('aws s3 cp s3://shaina/volume-archive/EB+MO_D0-D80_fragments/my_CM_D3_R1_fragment.sort.bed.gz /volume/NEW_ATAC_SEQ/rep_1/')
os.system('aws s3 cp s3://shaina/volume-archive/EB+MO_D0-D80_fragments/my_CM_D3_R1_fragment.sort.bed.gz.tbi /volume/NEW_ATAC_SEQ/rep_1/')
# Out:
# Completed 82.8 MiB/1.1 GiB (150.2 MiB/s) with 1 file(s) remaining
# Completed 153.2 MiB/1.1 GiB (203.9 MiB/s) with 1 file(s) remaining
# Completed 239.0 MiB/1.1 GiB (250.7 MiB/s) with 1 file(s) remaining
# Completed 322.2 MiB/1.1 GiB (279.4 MiB/s) with 1 file(s) remaining
# Completed 407.2 MiB/1.1 GiB (300.5 MiB/s) with 1 file(s) remaining
# Completed 494.8 MiB/1.1 GiB (318.0 MiB/s) with 1 file(s) remaining
# Completed 570.0 MiB/1.1 GiB (324.3 MiB/s) with 1 file(s) remaining
# Completed 655.5 MiB/1.1 GiB (334.7 MiB/s) with 1 file(s) remaining
# Completed 747.0 MiB/1.1 GiB (345.9 MiB/s) with 1 file(s) remaining
# Completed 838.5 MiB/1.1 GiB (355.3 MiB/s) with 1 file(s) remaining
# Completed 923.0 MiB/1.1 GiB (360.5 MiB/s) with 1 file(s) remaining
# Completed 1016.8 MiB/1.1 GiB (368.2 MiB/s) with 1 file(s) remaining
# Completed 1.1 GiB/1.1 GiB (370.4 MiB/s) with 1 file(s) remaining
# Completed 1.1 GiB/1.1 GiB (367.5 MiB/s) with 1 file(s) remaining
# ...

# %%
# !pip install MACS2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for MACS2: filename=MACS2-2.2.9.1-cp310-cp310-linux_x86_64.whl size=1838431 sha256=fc1a55b749ae2260a243c007b616508a1b70614a56b04f3b8d0faccdf5ae3287
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/99/af/5d/88c35ca0afcbc95d9338d97ae48934f1e8e73ed9a8c9c98ae0
# Successfully built MACS2
# DEPRECATION: distro-info 1.1build1 has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of distro-info or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
# !which macs2
# Out:
# /home/ubuntu/.local/bin/macs2
